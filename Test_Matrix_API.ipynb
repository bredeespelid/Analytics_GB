# %% [markdown]
# <a href="https://colab.research.google.com/github/bredeespelid/Analytics_GB/blob/main/Test_Matrix_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from itertools import product
import json

def batch_addresses(addresses, batch_size):
    """
    Splits a list of addresses into smaller batches.
    :param addresses: List of addresses.
    :param batch_size: Maximum batch size.
    :return: List of address batches.
    """
    for i in range(0, len(addresses), batch_size):
        yield addresses[i:i + batch_size]

def get_distance_matrix(api_key, origins, destinations, mode="driving", units="metric", departure_time="now"):
    base_url = "https://api.distancematrix.ai/maps/api/distancematrix/json"
    params = {
        "origins": "|".join(origins),
        "destinations": "|".join(destinations),
        "mode": mode,
        "units": units,
        "departure_time": departure_time,
        "key": api_key,
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        response.raise_for_status()

# Full address list
addresses = [
    "Minde allé 35, Bergen, Norway",
    "Vestre Torggaten 2, Bergen, Norway",
    "Vetrlidsallmenningen 19, Bergen, Norway",
    "Marken 1 5017, Bergen, Norway",
    "Nedre Korskirkeallmenningen 12, Bergen, Norway",
    "Christies gate 10 5016, Bergen, Norway",
    "Inndalsveien 6, Bergen, Norway",
    "Muséplassen 3, Bergen, Norway",
    "Damsgårdsveien 59, Bergen, Norway",
    "Myrdalsvegen 2, Bergen, Norway",
    "Lagunen Storsenter 5239, Bergen, Norway"
]

# API key
API_KEY = "BfszMUU1CcbMM6xvCCH3RTqcXzrGOH0PGfcKm90ih8QvAiKiUTwTRn4aGXfUiN6p"

# Max number of elements allowed per request
MAX_ELEMENTS = 100

# Calculate batch size
batch_size = MAX_ELEMENTS // len(addresses)

# Create address batches
batches = list(batch_addresses(addresses, batch_size))

# Store results
results_json = []

# Process batches
try:
    for origin_batch in batches:
        for destination_batch in batches:
            response = get_distance_matrix(API_KEY, origin_batch, destination_batch, mode="driving", units="metric", departure_time="now")

            # Extract relevant data
            for i, row in enumerate(response["rows"]):
                for j, element in enumerate(row["elements"]):
                    result = {
                        "origin": origin_batch[i],
                        "destination": destination_batch[j],
                        "status": element["status"]
                    }
                    if element["status"] == "OK":
                        result["duration"] = element["duration"]["text"]
                    results_json.append(result)

    # Output full JSON response
    print(json.dumps(results_json, indent=4))

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# [
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "3 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "3 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Minde all\u00e9 35, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "20 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "20 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "21 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Mus\u00e9plassen 3, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Minde all\u00e9 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "18 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Mus\u00e9plassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Damsg\u00e5rdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "23 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "22 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     }
# ]

# %%
# Output full JSON response with UTF-8 encoding
print(json.dumps(results_json, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "3 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "2 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "3 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "4 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "9 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "6 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "7 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "12 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "8 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "5 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Minde allé 35, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Vestre Torggaten 2, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "20 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Marken 1 5017, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "20 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "21 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Christies gate 10 5016, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "13 mins"
#     },
#     {
#         "origin": "Inndalsveien 6, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Muséplassen 3, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Damsgårdsveien 59, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "16 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Minde allé 35, Bergen, Norway",
#         "status": "OK",
#         "duration": "11 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Vestre Torggaten 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Vetrlidsallmenningen 19, Bergen, Norway",
#         "status": "OK",
#         "duration": "18 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Marken 1 5017, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Nedre Korskirkeallmenningen 12, Bergen, Norway",
#         "status": "OK",
#         "duration": "19 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Christies gate 10 5016, Bergen, Norway",
#         "status": "OK",
#         "duration": "15 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Inndalsveien 6, Bergen, Norway",
#         "status": "OK",
#         "duration": "10 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Muséplassen 3, Bergen, Norway",
#         "status": "OK",
#         "duration": "17 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Damsgårdsveien 59, Bergen, Norway",
#         "status": "OK",
#         "duration": "14 mins"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     },
#     {
#         "origin": "Myrdalsvegen 2, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "23 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Myrdalsvegen 2, Bergen, Norway",
#         "status": "OK",
#         "duration": "22 mins"
#     },
#     {
#         "origin": "Lagunen Storsenter 5239, Bergen, Norway",
#         "destination": "Lagunen Storsenter 5239, Bergen, Norway",
#         "status": "OK",
#         "duration": "1 min"
#     }
# ]

# %%
import pandas as pd

clean = json.dumps(results_json, indent=4, ensure_ascii=False)

df = pd.DataFrame(results_json)
